# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_best-selling_fiction_authors"

# %%
page = requests.get(url)

# %%
Soup = BeautifulSoup(page.text,'html')

# %%
Soup.find_all('table')[0]
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Author</th>
# <th data-sort-type="number">Min. estimated sales</th>
# <th data-sort-type="number">Max. estimated sales</th>
# <th>Original language</th>
# <th>Genre and/or major works</th>
# <th data-sort-type="number">Number of books</th>
# <th>Nationality
# </th></tr>
# <tr>
# <td><span class="nowrap"><span data-sort-value="Shakespeare, William"><span class="vcard"><span class="fn"><a href="/wiki/William_Shakespeare" title="William Shakespeare">William Shakespeare</a></span></span></span></span>
# </td>
# <td data-sort-value="2,000 million">2 billion<sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </td>
# <td data-sort-value="4,000 million">4 billion<sup class="reference" id="cite_ref-Shakespeare_2-0"><a href="#cite_note-Shakespeare-2"><span class="cite-bracket">[</span>2<span class="cite-bracket">]</span></a></sup>
# </td>
# ...

# %%
Soup.find('table', class_ = 'wikitable sortable')
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Author</th>
# <th data-sort-type="number">Min. estimated sales</th>
# <th data-sort-type="number">Max. estimated sales</th>
# <th>Original language</th>
# <th>Genre and/or major works</th>
# <th data-sort-type="number">Number of books</th>
# <th>Nationality
# </th></tr>
# <tr>
# <td><span class="nowrap"><span data-sort-value="Shakespeare, William"><span class="vcard"><span class="fn"><a href="/wiki/William_Shakespeare" title="William Shakespeare">William Shakespeare</a></span></span></span></span>
# </td>
# <td data-sort-value="2,000 million">2 billion<sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </td>
# <td data-sort-value="4,000 million">4 billion<sup class="reference" id="cite_ref-Shakespeare_2-0"><a href="#cite_note-Shakespeare-2"><span class="cite-bracket">[</span>2<span class="cite-bracket">]</span></a></sup>
# </td>
# ...

# %%
table.find_all('th')
# Out:
# [<th>Author</th>,
#  <th data-sort-type="number">Min. estimated sales</th>,
#  <th data-sort-type="number">Max. estimated sales</th>,
#  <th>Original language</th>,
#  <th>Genre and/or major works</th>,
#  <th data-sort-type="number">Number of books</th>,
#  <th>Nationality
#  </th>]

# %%
column = table.find_all('th')
column
# Out:
# [<th>Author</th>,
#  <th data-sort-type="number">Min. estimated sales</th>,
#  <th data-sort-type="number">Max. estimated sales</th>,
#  <th>Original language</th>,
#  <th>Genre and/or major works</th>,
#  <th data-sort-type="number">Number of books</th>,
#  <th>Nationality
#  </th>]

# %%
column = [title.text.strip() for title in column]
print(column)
# Out:
# ['Author', 'Min. estimated sales', 'Max. estimated sales', 'Original language', 'Genre and/or major works', 'Number of books', 'Nationality']

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = column)
df
# Out:
# Empty DataFrame
# Columns: [Author, Min. estimated sales, Max. estimated sales, Original language, Genre and/or major works, Number of books, Nationality]
# Index: []

# %%
books_table = table.find_all('tr')

# %%
for book in books_table[1:]:
    Authors_book_table = book.find_all('td')
    books_row_data =[data.text.strip() for data in Authors_book_table]
    
    length = len(df)
    df.loc[length] = books_row_data

# %%
df
# Out:
#                   Author Min. estimated sales Max. estimated sales  \
# 0    William Shakespeare         2 billion[1]         4 billion[2]
# 1        Agatha Christie         2 billion[3]         4 billion[2]
# 2       Barbara Cartland       500 million[4]         1 billion[5]
# 3         Danielle Steel       500 million[6]       800 million[7]
# 4         Harold Robbins       750 million[8]       750 million[9]
# ..                   ...                  ...                  ...
# 97      Seiichi Morimura                          100 million[168]
# 98    Mary Higgins Clark     100 million[169]     100 million[170]
# 99          Penny Jordan      90 million[171]     100 million[172]
# 100    Patricia Cornwell                          100 million[173]
# 101      Terry Pratchett          122 million          122 million
#
#     Original language                           Genre and/or major works  \
# 0             English  Plays and poetry, e.g. Romeo and Juliet, Macbe...
# ...
