# %% [raw]
# pip install seaborn

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
file_path ='D:\Internship\Visulaization\Employee Dataset.csv'
df = pd.read_csv(file_path)
print(df)
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 0    0      A   36               5                 5    2297
# 1    1      A   26               3                 5    1134
# 2    2      A   61               8                 1    4969
# 3    3      O   24               3                 6     902
# 4    4      O   39               6                 2    3574
# 5    5      O   32               5                 3    2761
# 6    6     AB   25               4                 6    1484
# 7    7      B   39               8                 6    3809
# 8    8      A   32               5                 6    2065
# 9    9      A   28               4                 8    1020
# 10  10      A   30               6                 9    1950
# 11  11      O   40               7                 1    4387
# 12  12      O   23               3                 2    1830
# 13  13      O   30               6                 8    2182
# ...

# %%
df.head()
# Out:
#    id groups  age  healthy_eating  active_lifestyle  salary
# 0   0      A   36               5                 5    2297
# 1   1      A   26               3                 5    1134
# 2   2      A   61               8                 1    4969
# 3   3      O   24               3                 6     902
# 4   4      O   39               6                 2    3574

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   groups            50 non-null     object
#  2   age               50 non-null     int64
#  3   healthy_eating    50 non-null     int64
#  4   active_lifestyle  50 non-null     int64
#  5   salary            50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %%
sns.barplot(x='id',y='salary',data = df)
# Out:
# <Axes: xlabel='id', ylabel='salary'>

# %%
sns.boxplot(x='age', y='salary', data=df)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
  sns.violinplot(x='id', y='groups', data=df)
# Out:
# <Axes: xlabel='id', ylabel='groups'>

# %%
sns.scatterplot(x='age',y='healthy_eating',data=df)
# Out:
# <Axes: xlabel='age', ylabel='healthy_eating'>

# %%
sns.barplot(x='groups', y='salary', data=df)
# Out:
# <Axes: xlabel='groups', ylabel='salary'>

# %%
sns.histplot(df['salary'], bins=10, kde=True)
# Out:
# C:\Users\Suriya Elaiyarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.lineplot(x='age', y='salary', hue='groups', data=df, marker='o')
# Out:
# C:\Users\Suriya Elaiyarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Suriya Elaiyarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='salary'>

# %%
sns.histplot(df['salary'], bins=10, kde=True)
# Out:
# C:\Users\Suriya Elaiyarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='salary', ylabel='Count'>
